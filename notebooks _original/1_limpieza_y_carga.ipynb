# %%
import pandas as pd
import os
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/My Drive/SERIE HISTORICA INVERSIONES MOP 2010-2021/
# Out:
# /content/drive/My Drive/SERIE HISTORICA INVERSIONES MOP 2010-2021

# %%
# !ls
# Out:
# LICENSE.md  README.md	      serie_historica_inversiones_mop_2010-2021.xls
# notebooks   requirements.txt

# %%
pip install --upgrade xlrd
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
df_inversion_historica = pd.read_excel('serie_historica_inversiones_mop_2010-2021.xls', sheet_name='Hoja1', skiprows=4)
df_inversion_historica['SHEET'] = 'INVERSIONES'

# %%
df_inversion_historica.head()
# Out:
#     AÑO                    SERVICIO  SUBTITULO  ITEM              REGIÓN  \
# 0  2010  Dirección de Arquitectura          31     2  Arica y Parinacota
# 1  2010  Dirección de Arquitectura          31     2  Arica y Parinacota
# 2  2010  Dirección de Arquitectura          31     2            Coquimbo
# 3  2010  Dirección de Arquitectura          31     2            Coquimbo
# 4  2010  Dirección de Arquitectura          31     2            Coquimbo
#
#           BIP  ASIG                                             NOMBRE  \
# 0  30088379-0     2  AMPLIACION OFICINAS MOP EDIFICIO SERVICIOS PUB...
# 1  30088379-0     4  AMPLIACION OFICINAS MOP EDIFICIO SERVICIOS PUB...
# 2  20107677-0     2             CONSTRUCCION EDIFICIO M.O.P. LA SERENA
# 3  20107677-0     4             CONSTRUCCION EDIFICIO M.O.P. LA SERENA
# 4  20107677-0     5             CONSTRUCCION EDIFICIO M.O.P. LA SERENA
#
#    INVERSIÓN (MILES DE $ DE CADA AÑO)  INVERSIÓN (MILES DE $ AÑO 2021)  \
# ...

# %%
df_inversion_historica = pd.read_excel('serie_historica_inversiones_mop_2010-2021.xls', sheet_name='Hoja1', skiprows=4)
df_inversion_historica['SHEET'] = 'INVERSIONES'
len(df_inversion_historica)
# Out:
# 27258

# %%
df_inversion_historica_new = df_inversion_historica.dropna(how='any')
len(df_inversion_historica_new)
# Out:
# 26963

# %%
df_inversion_historica_new.dtypes
# Out:
# AÑO                                     int64
# SERVICIO                               object
# SUBTITULO                               int64
# ITEM                                    int64
# REGIÓN                                 object
# BIP                                    object
# ASIG                                    int64
# NOMBRE                                 object
# INVERSIÓN (MILES DE $ DE CADA AÑO)    float64
# INVERSIÓN (MILES DE $ AÑO 2021)       float64
# SERVICIO2                              object
# TRANSANTIAGO                           object
# PROGRAMA                               object
# PROVINCIA                              object
# COMUNA                                 object
# SHEET                                  object
# dtype: object

# %%
df_inversion_historica_new = df_inversion_historica_new[['AÑO', 'SERVICIO', 'REGIÓN', 'NOMBRE', 'INVERSIÓN (MILES DE $ AÑO 2021)', 'PROGRAMA', 'COMUNA']]

# %%
df_inversion_historica_new.to_csv('notebooks/data/clean_inversiones.csv', index=None)
